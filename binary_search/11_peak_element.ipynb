# %% [markdown]
# ![Screenshot 2024-08-01 122909.png](<attachment:Screenshot 2024-08-01 122909.png>)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # problem
#
#
# in case of isngle peak we didnot face problem
#
# for multiple peak if we ge stuck in local minima then we didnot mentioned where to move that we will change
# here for multiple peak
#
#
# if we get stuck in local minima then move anyside to move out of local minima
# becaise every side of local minima have a local maxima  i.e peak
