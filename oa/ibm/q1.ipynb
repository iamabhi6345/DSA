# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def minflip(s):
    n = len(s)
    count=0
    for i in range(0,n,2):
        if s[i]!=s[i+1]:
            count+=1
    return count

# %%
print(minflip("100110"))
print(minflip("101011"))
# Out:
# 3
# 2
